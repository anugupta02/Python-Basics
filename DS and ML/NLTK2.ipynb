# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()                 # lemmatizer used for verbs,noun,adjective,
print(lemmatizer.lemmatize('played',pos="v"))
print(lemmatizer.lemmatize('playing',pos="n"))
print(lemmatizer.lemmatize('playing',pos="a"))
print(lemmatizer.lemmatize('playing',pos="r"))
print(lemmatizer.lemmatize('stones',pos="v"))
# Out:
# play
# playing
# playing
# playing
# stone

# %%
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
stemmer=PorterStemmer()
lemmatizer=WordNetLemmatizer()
print(stemmer.stem('stones'))
print(stemmer.stem('speaking'))
print(stemmer.stem('bedroom'))
print(stemmer.stem('jaked'))
print(stemmer.stem('lisa'))
print(stemmer.stem('purpled'))
print('------------------------')
print(lemmatizer.lemmatize('stones'))
print(lemmatizer.lemmatize('speaking'))
print(lemmatizer.lemmatize('bedrooms'))
print(lemmatizer.lemmatize('jaked'))
print(lemmatizer.lemmatize('lisa'))
print(lemmatizer.lemmatize('purple'))
# Out:
# stone
# speak
# bedroom
# jake
# lisa
# purpl
# ------------------------
# stone
# speaking
# bedroom
# jaked
# lisa
# purple

# %%
# for speech code, we use PunktSentenceTokenizer
import nltk
from nltk.tokenize import PunktSentenceTokenizer
document='Whether Abhishek you\' re new to'
sentences=nltk.sent_tokenize(document)
for sent in sentences:
    print(nltk.pos_tag(nltk.word_tokenize(sent)))
# Out:
# [('Whether', 'NNP'), ('Abhishek', 'NNP'), ('you', 'PRP'), ("'", "''"), ('re', 'VB'), ('new', 'JJ'), ('to', 'TO')]

# %%
#read content from website  and count the frequency of words
from bs4 import BeautifulSoup
import urllib.request
import nltk
from nltk.corpus import stopwords
url='http://www.php.net'
content=urllib.request.urlopen(url)
con=BeautifulSoup(content,'html.parser')
text=con.get_text(strip=True)                     #strip removes spaces
#print(text)
tokens=[t for t in text.split()]
freq=nltk.FreqDist(tokens)                #freqdist count words
#sw=set(stopwords.words('english'))
#print(len(sw))
for key,val in freq.items():
    #if key not in sw:
    print(key,':',val)
# Out:
# PHP: : 1
# Hypertext : 1
# PreprocessorDownloadsDocumentationGet : 1
# InvolvedHelpGetting : 1
# StartedIntroductionA : 1
# simple : 1
# tutorialLanguage : 1
# ReferenceBasic : 1
# syntaxTypesVariablesConstantsExpressionsOperatorsControl : 1
# StructuresFunctionsClasses : 1
# and : 96
# ObjectsNamespacesErrorsExceptionsGeneratorsReferences : 1
# ExplainedPredefined : 1
# VariablesPredefined : 1
# ExceptionsPredefined : 1
# Interfaces : 1
# ClassesContext : 1
# options : 1
# parametersSupported : 1
# Protocols : 1
# WrappersSecurityIntroductionGeneral : 1
# considerationsInstalled : 1
# as : 2
# CGI : 1
# binaryInstalled : 1
# an : 11
# Apache : 1
# moduleSession : 1
# SecurityFilesystem : 1
# SecurityDatabase : 1
# SecurityError : 1
# ReportingUsing : 1
# Register : 1
# GlobalsUser : 1
# Submitted : 1
# DataMagic : 1
# QuotesHiding : 1
# PHPKeeping : 1
# CurrentFeaturesHTTP : 1
# authentication : 1
# with : 3
# PHPCookiesSessionsDealing : 1
# XFormsHandling : 1
# file : 1
# ...

# %% [markdown]
# pip install tweepy
# pip install texblob
# developer.twitter.com
# create app
